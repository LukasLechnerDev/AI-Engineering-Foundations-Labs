# %% [markdown]
# # Introduction
#
# Up until now, we have only worked with a small number of parameters when calling an LLM API with client.responses.create:
# - model
# - instructions
# - input
# - text
#
# In this module, we are going to take a closer look at these parameters and explore new ones that are important.
#
# OpenAI API Reference: https://developers.openai.com/api/reference/resources/responses/methods/create
