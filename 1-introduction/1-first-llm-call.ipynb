# %%
import os
from dotenv import load_dotenv
from openai import OpenAI

# %%
# load_dotenv will define all variables from the .env files as environment variables
load_dotenv(override=True)

# Here we read the API key from the environment variable
api_key = os.getenv('OPENAI_API_KEY')

if not api_key:
    print("No API key defined in the .env file! Please add your OpenAI API key to the .env file - see troubleshooting notebook")
elif not api_key.startswith("sk-proj-"):
    print("The API key has the wrong format - it should start with 'sk-proj-'")
else:
    print("API key was defined with the correct format!")
# Out:
# API key was defined with the correct format!

# %%
prompt = "This is my first programmatic interaction with an LLM - I'm so exited!"

messages = [{"role": "user", "content": prompt}]

messages
# Out:
# [{'role': 'user',
#   'content': "This is my first programmatic interaction with an LLM - I'm so exited!"}]

# %%
openai = OpenAI()

response = openai.chat.completions.create(model="gpt-5-mini", messages=messages)
print(response.choices[0].message.content)
# Out:
# Welcome — and congrats on your first programmatic LLM interaction! I’m excited too. I can help write code, explain concepts, draft messages, plan projects, debug, generate creative text, and more. A few quick tips and examples to get the most out of this session, then you can tell me what you want to try.
#
# Quick tips for good prompts
# - Say exactly what you want and why (the goal).
# - Give context (language, constraints, audience, examples).
# - Specify the output format if you need one (JSON, bullet list, code, short summary).
# - Ask for step-by-step, alternatives, or tests if useful.
# - Use follow-ups: “explain this line,” “make it shorter,” “optimize it,” etc.
#
# Example starter prompts you can copy or modify
# - “Write a simple Python script that reads a CSV of sales and outputs total sales per month.”
# - “Explain recursion like I’m five, then give a one-paragraph technical summary.”
# - “Draft a polite email asking for an extension on a project deadline (100–150 words).”
# - “Compare React and Vue for a small team building a dashboard; pros and cons.”
# - “Give me 5 meal ideas for a vegetarian, low-carb diet with estimated calories.”
# - “Find the bug in this Python function: def f(x): return x * x +” (paste code).
#
# Small code example (Python)
# def hello(name):
#     return f"Hello, {name}!"
#
# print(hello("Sam"))
#
# Follow-up commands that are useful
# - “Explain each line.”
# - “Make it more efficient.”
# - “Convert this to JavaScript.”
# - “Add unit tests.”
# - “Shorten to one paragraph.”
# - “Give 3 alternatives.”
#
# Safety & limitations
# - I can make mistakes — verify important facts and test code before using it in production.
# - Don’t share sensitive personal data or secrets.
# - I don’t have real-time web access unless you use a plugin or give data.
#
# Want to try something now?
# Tell me what you want (a task, a topic, code to fix, etc.), and how you’d like the answer formatted. If you’d like, pick one of the example prompts above and I’ll do it.
